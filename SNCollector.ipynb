# %% [markdown]
# # Сбор данных из ВКонтакте

# %% [markdown]
# Автор: Воробьев Юрий (https://vk.com/vorobyevyuri)
#
# Данный скрипт собирает данные постов в группе из социальной сети ВКонтакте
#
# Следуйте инструкциям

# %% [markdown]
# ## Скрипт 1 - Создание таблицы данных

# %% [markdown]
# ### Столбцы таблицы:
# * дата публикации (unix time) / конвертер: https://www.cy-pr.com/tools/time/
# * ссылка на публикацию
# * количество лайков
# * количество репостов

# %% [markdown]
# 1. Подключение библиотек

# %%
import requests

# %% [markdown]
# 2. Для получения токена перейдите по ссылке и скопируйте нужную часть в блок ниже
# https://oauth.vk.com/authorize?client_id=5453402&display=page&redirect_uri=http://localhost&scope=&response_type=token&v=5.53
# ![alt](https://api.monosnap.com/rpc/file/download?id=H72wV79ObVw7rLBfJO8T4jOJ25szXW)

# %%
token = '2fb0e77cfe900ca8f180debe5867a9cb3151e6bacf681b0a6d5b2ef6cb3e8cd07f95d013df3cc4415b684'

# %% [markdown]
#  3. Укажите id группы

# %%
group = -48632629

# %% [markdown]
# 4. Укажите выборку по постами (целочисленное значение):

# %%
posts = 100

# %% [markdown]
# 5. Запустите скрипт:

# %%
r = requests.get('https://api.vk.com/method/wall.get',params={'access_token':token,'owner_id':group,'count':posts,'v': 5.68})
post = r.json()['response']['items']
print('Дата публикации','|','          Ссылка         ','|','Лайки','|','Репосты')
for i in range(1,posts):
    post_date = post[i]['date']
    post_id = post[i]['id']
    group_id = post[i]['from_id']
    likes = post[i]['likes']['count']
    repost = post[i]['reposts']['count']
    print(post_date,'     |','vk.com/wall'+str(group_id)+'_'+str(post_id),'|',likes,'    |',repost)
# Out:
# Дата публикации |           Ссылка          | Лайки | Репосты
# 1590679017      | vk.com/wall-48632629_7602 | 2     | 0
# 1590678232      | vk.com/wall-48632629_7600 | 4     | 0
# 1590658893      | vk.com/wall-48632629_7597 | 6     | 0
# 1590480007      | vk.com/wall-48632629_7596 | 2     | 1
# 1590425821      | vk.com/wall-48632629_7594 | 1     | 1
# 1590257616      | vk.com/wall-48632629_7593 | 0     | 0
# 1590220032      | vk.com/wall-48632629_7523 | 20     | 3
# 1590132234      | vk.com/wall-48632629_7522 | 8     | 0
# 1590072807      | vk.com/wall-48632629_7520 | 14     | 1
# 1590001053      | vk.com/wall-48632629_7517 | 15     | 1
# 1589906826      | vk.com/wall-48632629_7512 | 13     | 0
# 1589898565      | vk.com/wall-48632629_7509 | 12     | 1
# 1589802734      | vk.com/wall-48632629_7507 | 19     | 3
# 1589790577      | vk.com/wall-48632629_7506 | 5     | 1
# 1589785228      | vk.com/wall-48632629_7505 | 1     | 0
# 1589643699      | vk.com/wall-48632629_7503 | 4     | 2
# 1589535241      | vk.com/wall-48632629_7502 | 3     | 1
# 1589334075      | vk.com/wall-48632629_7500 | 5     | 1
# 1589201661      | vk.com/wall-48632629_7499 | 3     | 2
# 1589199946      | vk.com/wall-48632629_7495 | 2     | 2
# 1589105275      | vk.com/wall-48632629_7494 | 3     | 0
# 1589041935      | vk.com/wall-48632629_7493 | 6     | 0
# 1588994565      | vk.com/wall-48632629_7492 | 5     | 0
# 1588858543      | vk.com/wall-48632629_7491 | 15     | 0
# 1586271663      | vk.com/wall-48632629_7271 | 40     | 0
# 1586213553      | vk.com/wall-48632629_7269 | 12     | 1
# 1586202505      | vk.com/wall-48632629_7268 | 1     | 1
# 1586198121      | vk.com/wall-48632629_7266 | 1     | 0
# 1586191595      | vk.com/wall-48632629_7265 | 15     | 0
# 1586177213      | vk.com/wall-48632629_7263 | 3     | 0
# 1586101216      | vk.com/wall-48632629_7257 | 9     | 0
# 1586085227      | vk.com/wall-48632629_7253 | 9     | 1
# 1586082542      | vk.com/wall-48632629_7252 | 5     | 0
# 1586027916      | vk.com/wall-48632629_7244 | 68     | 1
# 1585927448      | vk.com/wall-48632629_7239 | 19     | 0
# 1585905184      | vk.com/wall-48632629_7238 | 9     | 0
# 1585904155      | vk.com/wall-48632629_7237 | 16     | 1
# 1585846922      | vk.com/wall-48632629_7231 | 10     | 1
# 1585843747      | vk.com/wall-48632629_7228 | 11     | 2
# 1585829651      | vk.com/wall-48632629_7226 | 2     | 0
# 1585766905      | vk.com/wall-48632629_7224 | 1     | 0
# 1585670034      | vk.com/wall-48632629_7221 | 40     | 1
# 1585666348      | vk.com/wall-48632629_7217 | 16     | 1
# 1585586978      | vk.com/wall-48632629_7216 | 1     | 1
# 1585567321      | vk.com/wall-48632629_7215 | 5     | 0
# 1585421491      | vk.com/wall-48632629_7214 | 4     | 1

# %% [markdown]
# ## Скрипт 2 - Запись данных в файл

# %% [markdown]
# ### Расположение:
# Все созданные файлы создаются в корне пользователя, пример: C:\Users\\<имя_пользователя>
#
# ### Наименование:
# * Файл данных json - posts.json
# * Файл данных csv - posts_data.csv

# %% [markdown]
# 1. Подключение библиотек

# %%
import requests
import json
import csv
import pymongo
from time import sleep

# %% [markdown]
# 2. Для получения токена перейдите по ссылке и скопируйте нужную часть в блок ниже
# https://oauth.vk.com/authorize?client_id=5453402&display=page&redirect_uri=http://localhost&scope=&response_type=token&v=5.53
# ![alt](https://api.monosnap.com/rpc/file/download?id=H72wV79ObVw7rLBfJO8T4jOJ25szXW)

# %%
token = '563fbc6dc0b5b7916d1709141f1c13303d7a390ce8051ae11294b7e36b129d0f6fa436fc19dfee434b373'

# %% [markdown]
# 3. Укажите id группы

# %%
group_id = '-48632629'

# %% [markdown]
# 4. Укажите выборку по постами (целочисленное значение):

# %%
post = 100

# %% [markdown]
# 5. Укажите сдвиг выборки (целочисленное значение):

# %%
offset = 0

# %% [markdown]
# 6. Создание файла данных (json):

# %%
def write_json(data):
	with open('posts.json', 'w', encoding="utf-8") as file:
		json.dump(data, file, indent=2, ensure_ascii=False)

def main():
	
	r = requests.get('https://api.vk.com/method/wall.get',params={'access_token':token,'owner_id':group_id,'count':post,'offset':offset,'v':5.68})
	
	write_json(r.json())

if __name__ == '__main__':
	main()

# %% [markdown]
# 6. 1.|опционально| Вывод файла данных (json):

# %%
print (r.json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-501487144f27> in <module>
# ----> 1 print (r.json())
#
# NameError: name 'r' is not defined

# %% [markdown]
# 7. Создание файла данных (csv):

# %%
def write_csv(data):
	with open('posts_data.csv', 'a', encoding="utf-8") as file:
		writer = csv.writer(file)
		writer.writerow((data['likes'],
						 data['reposts'],
						 data['text']
						))

def get_data(postdict):
	try:
		post_id = postdict['id']
	except:
		post_id = 0
		
	try:
		likes = postdict['likes']['count']
	except:
		likes = 'zero'
	
	try:
		reposts = postdict['reposts']['count']
	except:
		reposts = 'zero'	
		
	try:
		text = postdict['text']
	except:
		reposts = '***'
		
	data = {
		'id': post_id,
		'likes': likes,
		'reposts': reposts,
		'text': text
	}
	
	return data

def main():

	all_posts = []

	sleep(1)
	r = requests.get('https://api.vk.com/method/wall.get',params={'access_token':token,'owner_id':group_id,'count':post,'offset':offset,'v':5.68})
	posts = r.json()['response']['items']

	all_posts.extend(posts)

	data_posts = []

	for postdict in all_posts:
		post_data = get_data(postdict)
		write_csv(post_data)

if __name__ == '__main__':
	main()

# %% [markdown]
# 7. 1.|опционально| Вывод файла данных (csv):

# %%
with open('posts_data.csv', 'r', encoding="utf-8") as fp:
    reader = csv.reader(fp, delimiter=',', quotechar='"')
    # next(reader, None)  # skip the headers
    data_read = [row for row in reader]
print(data_read)
# Out:
# [['4', '1', '}1 ИКТИБ НА УДАЛЕНКЕ \n \nГрафики добора баллов, пересдач и работы комиссий по приему задолженностей 👉🏻 http://ictis.sfedu.ru/grafiki-dobora-ballov/ \n \n❓Как получить социальную стипендию? \n \n1. Заполни заявление и подписать его.\n2. Сделай скан или качественное фото заявления и подтверждающего документа.\n3. Отправь сканы заявления и документа со своей почты sfedu на kumov@sfedu.ru. \nШаблоны документов тут https://vk.com/ictis_sfedu?w=wall-48632629_7300\n \n❓Как получить материальную поддержку? \n \n1. Заполни заявление и укажи одну или несколько причин из пункта 2.7 прикрепленного к посту положения.\n2. Подпиши заявление.\n3. Загрузи сканы или фотографии заявления и подтверждающих документов единым PDF-файлом по ссылке https://vk.cc/arUoRY в срок до 15.05.2020 г. (авторизация через @sfedu.ru).\nШаблоны документов тут https://vk.com/ictis_sfedu?w=wall-48632629_7300\n\n📞По вопросам получения справок об оказании адресной помощи для оформления социальной стипендии обращаться по телефону +7 (8634) 47-72-06 или +7 (8634) 47-72-16\n \n❓Как получить справки от дирекции? \n \n1. Перейди по ссылке: https://forms.office.com/Pages/ResponsePage.aspx?id=XUO6GWzkakOE8hsB5pPkgJQJiPBUcYBHs2pnMbkh239URFgySlk3V05MSTJXVU5GMkQ3M1ZNT1JXRS4u\n2. Войди через учётную запись @sfedu.ru.\n3. Заполни форму.\n \nПосле перехода университета в обычный режим работы, принеси все оригиналы документов в И-205.'], [], ['2', '1', '}1 УЧАСТВУЙ В DS-СОРЕВНОВАНИИ\n\n💁\u200d♂Профессиональное сообщество NewTechAudit в области внутреннего аудита, контроля и управления рисками хочет привлечь квалифицированных молодых специалистов ВУЗов в области Data Science. К участию приглашаются студенты, магистранты и аспиранты ВУЗов РФ.\n\n📍Где: на платформе Kaggle\n📝Необходимо зарегистрироваться на сайте Kaggle, присоединиться к соревнованию и начать свои исследования, выкладывать можно по 5 решений в день и отслеживать свою позицию на лидерборде.\n\n🤓Этапы соревнований:\n27.05.2020 - 27.06.2020 - размещение участниками своих решений на платформе Kaggle;\n29.06.2020 - 07.07.2020 - подведение комиссией итогов  по соревнованию и определение победителей;\n08.07.2020 - 10.07.2020 - онлайн-объявление победителей.\n\nУчастникам предстоит предсказать координаты 194 точек лица на фотографиях, в тренировочном Dataset 2000 фотографий, в тестовом около 300.\n\n🥳По итогам соревнований лучшим кандидатам будет представлена  возможность пройти стажировку в крупнейшем банке РФ.'], [], ['1', '1', '}1 FUSHION ХАКАТОН\n\n👨\u200d💻FUSION ХАКАТОН все ближе.\n\n📝Отправляй заявку на участие в 1 этапе в ЛС сообщества и узнавай подробности.\n📍Обязательное условие - быть подписанным на [https://vk.com/fusion__team|Fusion Team].\n\n🙋\u200d♀К участию приглашаются: магистранты, аспиранты, выпускники ВУЗов, а также все, кто самостоятельно пробует свои силы в вебе и не имеет опыта коммерческой разработки. \n\n💁🏻\u200d♂За обновлением информации следи в сообществе Fusion Team.'], [], ['0', '0', '}1 ПРИГЛАШАЕМ МОЛОДЫХ СПЕЦИАЛИСТОВ\n\n🙋🏻\u200d♂️Компания CRMGURU приглашает молодых специалистов начать или продолжить путь в направлении разработки.\n\n💁🏻\u200d♀️От тебя нужны базовые знания:\n- C#;\n- Понимание, как устроены реляционные БД;\n- Понимание основ работы ASP.NET.\n\nБудет плюсом:\n- Знание #Javascript на начальном уровне;\n- Умение работать с SQL;\n- Минимальный опыт с ORM.\n\n😍Тебя ждет:\n- #Удаленка (от стажировки до дальнейшей работы);\n- Возможность работы в команде единомышленников и профессионалов;\n- Возможность стать частью крупных брендов и корпораций.\n\n🙋🏻Пиши:\nSkype или Telegram: artalex1234\n📥 hr@crmguru.ru'], [], ['20', '3', 'День открытых дверей магистратуры ИКТИБ ЮФУ\n\nПросим по итогам встречи пройти простенький опрос:\nhttps://forms.office.com/Pages/ResponsePage.aspx?id=XUO6GWzkakOE8hsB5pPkgPV5x15XN19Ns51gwU30v19UQkwwOFFGMkJHUVYyTkZGMDNaQjlNTk9RTy4u'], [], ['8', '0', '😉В конце апреля мы провели день открытых дверей в онлайне для поступающих на программы бакалавриата и спец ...

# %% [markdown]
# ## Скрипт 3 - Загрузка данных в хранилище

# %% [markdown]
# ### Расположение:
# Данные загружаются в БД "ictis", коллекцию "group"

# %%
my_client = pymongo.MongoClient(
'mongodb+srv://YuriV:Juraass123@sncollector-ytivf.azure.mongodb.net/test?retryWrites=true&w=majority'
)

my_database = my_client.ictis3
my_collection = my_database.group


def save_posts(posts):
    flat_posts = []
    for post in posts:
        flat_posts.append({
            "post_id": post['id'],
            "date": post['date'],
            "text": post['text'],
            "likes_count": post['likes']['count'],
            "reposts_count": post['reposts']['count'],
            "comments_count": post['comments']['count'],
            "views_count": post['views']['count'],
            "url": "vk.com/wall{0}_{1}".format(post['owner_id'], post['id'])
        })

    my_collection.insert_many(flat_posts)


def main():

    # https://api.vk.com/method/users.get?user_id=210700286&v=5.52
    # https://oauth.vk.com/authorize?client_id=5453402&display=page&redirect_uri=http://localhost&scope=&response_type=token&v=5.53
    # e9c870e462f3976bc3dcfb2cec433656246127bcc76bfd562de09e92021c80087940c642d9d6251825e97

    all_posts = []
    date_x = 1559909249



    sleep(1)
    r = requests.get('https://api.vk.com/method/wall.get',params={'access_token':token,'owner_id':group_id,'count':postint,'offset':offset,'v':5.68})
    posts = r.json()['response']['items']
    save_posts(posts)
    #posts = r.json()['response']

   
if __name__ == '__main__':
    main()
